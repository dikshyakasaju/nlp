# %%
import pandas as pd

# %%
df = pd.read_excel("final.xlsx")

# %%
df
# Out:
#                                                  Title       Field of work  \
# 0                       New indignation, new alignment  Active Citizenship
# 1                                      Akshara Khazana           Education
# 2                Uncommon Ground - A CULTURE OF ENOUGH     Uncommon Ground
# 3    Our mission is safe and sustainable water for all               Water
# 4              Anna movement has lost its focus: Hande     Uncommon Ground
# ..                                                 ...                 ...
# 894                                                NaN                 NaN
# 895                                                NaN                 NaN
# 896                                                NaN                 NaN
# 897                                                NaN                 NaN
# 898                                                NaN                 NaN
#
# ...

# %%
sentence = "Dikshya loves gaming but Kasaju also loves to code"

# %%
names = ["Kasaju", "Pradhan", "Dikshya"]

# %%
for name in names:
    for word in sentence:
        if name == word:
            print(word)

# %%
sentence
# Out:
# 'Dikshya loves gaming and she also loves to code'

# %%
import re

search_list = ['one', 'two', 'there']
long_string = 'some one long two phrase three'
if re.compile('|'.join(search_list),re.IGNORECASE).search(long_string): #re.IGNORECASE is used to ignore case
    long_string.replace(search_list[0], " ")
else:
    pass

# %%
re.compile('|'.join(search_list),re.IGNORECASE).search(long_string)
# Out:
# <re.Match object; span=(5, 8), match='one'>
